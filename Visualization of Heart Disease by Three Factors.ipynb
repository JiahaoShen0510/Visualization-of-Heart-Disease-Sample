# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data0=pd.read_csv("heart-disease.csv")
data0
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data0.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
over_50=data0[data0["age"]>50]

# %%
over_50.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean    59.375000    0.668269    0.918269  134.802885  252.846154    0.187500
# std      5.603118    0.471971    1.062334   18.541104   54.382572    0.391254
# min     51.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     55.000000    0.000000    0.000000  121.500000  215.500000    0.000000
# 50%     58.500000    1.000000    0.000000  132.000000  246.000000    0.000000
# 75%     63.000000    1.000000    2.000000  145.000000  283.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.490385  144.552885    0.375000    1.210096    1.341346    0.889423
# ...

# %%
over_50.sort_values("age")
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 73    51    1   0       140   261    0        0      186      1      0.0
# 140   51    0   2       120   295    0        0      157      0      0.6
# 50    51    0   2       130   256    0        0      149      0      0.5
# 235   51    1   0       140   299    0        1      173      1      1.6
# 34    51    1   3       125   213    0        0      125      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 151   71    0   0       112   149    0        1      125      0      1.6
# 25    71    0   1       160   302    0        1      162      0      0.4
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 238   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 73       2   0     2       1
# 140      2   0     2       1
# ...

# %%
figure, (ax1,ax2,ax3)=plt.subplots(3,1,sharex=True,figsize=(10,10))

scatter1=ax1.scatter(over_50["age"],over_50["trestbps"],c=over_50["target"],cmap="inferno")
ax1.set(ylabel="Resting Blood Pressure")

scatter2=ax2.scatter(over_50["age"],over_50["thalach"],c=over_50["target"],cmap="inferno")
ax2.set(ylabel="Maximum Heart Rate ")

scatter3=ax3.scatter(over_50["age"],over_50["chol"],c=over_50["target"],cmap="inferno")
ax3.set(xlabel="Age",ylabel="cholesterol test")

ax1.axhline(over_50["trestbps"].mean(),linestyle="--")
ax2.axhline(over_50["thalach"].mean(),linestyle="--")
ax3.axhline(over_50["chol"].mean(),linestyle="--")


ax1.legend(*scatter1.legend_elements(),title="target")

figure.suptitle("Heart Disease Analysis",fontsize=20,fontweight="bold");

# %%
figure.savefig("Heart Disease Analysis.png")
